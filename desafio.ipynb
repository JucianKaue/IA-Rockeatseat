# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dicionário de faturamento
dict_faturamento = {
    'data_ref': [
        '2023-01-01', 
        '2020-02-01', 
        '2021-03-01', 
        '2022-04-01', 
        '2023-05-01',
        '2023-06-01', 
        '2020-07-01', 
        '2021-08-01', 
        '2022-09-01', 
        '2023-10-01',
        '2022-11-01', 
        '2023-12-01',
        ],
    'valor': [
        400000, 
        890000, 
        760000, 
        430000, 
        920000,
        340000, 
        800000, 
        500000, 
        200000, 
        900000,
        570000, 
        995000,
        ]
}

# %%
df_faturamento = pd.DataFrame(dict_faturamento)
data_ref_label = ["Janeiro", "Fevereiro", "Março", "Abril", "Maio", "Junho", "Julho", "Agosto", "Setembro", "Outubro", "Novembro", "Dezembro"]

# %%
df_faturamento['valor'].mean()
# Out:
# 642083.3333333334

# %%
plt.figure(figsize=(16,9))
plt.bar(data_ref_label, df_faturamento['valor'])
plt.xlabel('Data')
plt.ylabel('Faturamento')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(16,9))
plt.xlabel('Data')
plt.ylabel('Faturamento')
plt.plot(data_ref_label, df_faturamento['valor'])
